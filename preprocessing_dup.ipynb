# %%
import os
import pdfplumber
from pdf2image import convert_from_path
import pytesseract
import numpy as np
from PIL import Image
import easyocr
import json
import re

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
def extract_paragraphs_with_ocr(pdf_path):
    structured_blocks = []
    page_sizes = {}
    order = 0

    with pdfplumber.open(pdf_path) as pdf:
        for page_idx, page in enumerate(pdf.pages, 0):
            page_sizes[str(page_idx)] = {"width": page.width, "height": page.height}
            # Try to extract normal lines first
            lines = list(page.extract_text_lines())
            if lines and any(line.get("text", "").strip() for line in lines) and len(lines)>=5:
                # (Use your previous merging logic)
                for line in lines:
                    block = {
                        "box": [line["x0"], line["top"], line["x1"], line["bottom"]],
                        "text": line["text"],
                        "page": page_idx,
                        "id": order,    
                        "order": order
                    }
                    structured_blocks.append(block)
                    order += 1
            else:
                # If no text, do OCR
                pil_img = page.to_image(resolution=300).original
                ocr_text = pytesseract.image_to_string(pil_img)
                block = {
                    "box": [0,0,page.width,page.height],
                    "text": ocr_text,
                    "page": page_idx,
                    "id": order,
                    "order": order
                }
                structured_blocks.append(block)
                order += 1

    result = {
        "contents": structured_blocks
    }
    return result

# %%
input_folder = "./input"
output_folder = "./output"

for fname in os.listdir(input_folder):
    if fname.lower().endswith(".pdf"):
        pdf_path = os.path.join(input_folder, fname)
        out_path = os.path.join(output_folder, os.path.splitext(fname)[0] + ".json")
        structured = extract_paragraphs_with_ocr(pdf_path)
        with open(out_path, "w", encoding="utf-8") as f:
            json.dump(structured, f, indent=2)
        print(f"Extracted structure for {fname} -> {out_path}")

# %% [markdown]
# <pre>
# Model input:
# {
#     "box": [_, _, _, _],
#     "text": "______",
#     "page": _,
#     "id": _
# }
#
# Model Output:
# {
#     "label": "_____",
#     "linking": [[_, _]],
#     "order":
# }
# </pre>

# %% [markdown]
# <h1>Main Model</h1>

# %%
import os
import json
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_recall_fscore_support
from tqdm import tqdm
import time
import pickle

class FocalLoss(nn.Module):
    def __init__(self, alpha=0.75, gamma=2.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = nn.functional.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        return focal_loss.mean()

class DocIENetDataset(Dataset):
    VALID_LABELS = {'title', 'section-title'}

    def __init__(self, input_files, output_files, tokenizer, max_length=64, label_encoder=None):
        self.data = []
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.order_counts_dict = {}

        if label_encoder is None:
            all_labels = set(['title', 'section-title'])
            self.label_encoder = LabelEncoder()
            self.label_encoder.fit(sorted(list(all_labels)))
        else:
            self.label_encoder = label_encoder

        self.link_counts = 0
        self.order_counts = 0
        for input_file, output_file in tqdm(zip(input_files, output_files), desc="Loading dataset"):
            self._process_file_pair(input_file, output_file)

        print(f"Dataset loaded with {len(self.data)} samples")
        print(f"Valid labels: {list(self.label_encoder.classes_)}")
        print(f"Total valid links: {self.link_counts}")
        print(f"Total items with reassigned orders: {self.order_counts}")
        print(f"Order distribution in dataset: {self.order_counts_dict}")

    def _process_file_pair(self, input_file, output_file):
        try:
            with open(input_file, 'r', encoding='utf-8') as f:
                input_data = json.load(f)
            with open(output_file, 'r', encoding='utf-8') as f:
                output_data = json.load(f)

            output_map = {item['id']: item for item in output_data.get('contents', [])}
            valid_ids = {item['id'] for item in output_data.get('contents', []) if item.get('label') in self.VALID_LABELS}

            for item in input_data.get('contents', []):
                item_id = item.get('id')
                if item_id not in output_map:
                    continue
                output_item = output_map[item_id]
                label = output_item.get('label', 'other')
                if label not in self.VALID_LABELS:
                    continue
                if label not in self.label_encoder.classes_:
                    continue

                page_num = item.get('page', 1)
                page_info = input_data.get('pages', {}).get(f'page{page_num}', 
                                                           input_data.get('pages', {}).get(str(page_num), 
                                                           {'width': 1000, 'height': 1000}))
                box = item.get('box', [0, 0, 0, 0])
                normalized_box = [
                    box[0] / page_info['width'],
                    box[1] / page_info['height'],
                    box[2] / page_info['width'],
                    box[3] / page_info['height']
                ]

                parent_id = 0
                for link in output_item.get('linking', []):
                    if len(link) == 2 and link[0] in valid_ids and link[1] in valid_ids and link[0] != 0 and link[1] != 0:
                        parent_id = link[1]
                        self.link_counts += 1
                        break

                if parent_id == 0:
                    for other_item in input_data.get('contents', []):
                        other_id = other_item.get('id')
                        if other_id != item_id and other_id in output_map:
                            other_label = output_map[other_id].get('label', 'other')
                            if other_label in self.VALID_LABELS:
                                other_box = other_item.get('box', [0, 0, 0, 0])
                                other_box_norm = [
                                    other_box[0] / page_info['width'],
                                    other_box[1] / page_info['height'],
                                    other_box[2] / page_info['width'],
                                    other_box[3] / page_info['height']
                                ]
                                dist = np.sqrt((normalized_box[0] - other_box_norm[0])**2 + (normalized_box[1] - other_box_norm[1])**2)
                                if dist < 0.2 and parent_id == 0:
                                    parent_id = other_id
                                    self.link_counts += 1
                                    break

                text = item.get('text', '') or '[EMPTY]'
                order = min(output_item.get('order', 0), 6)  # Cap at 6 based on GT distribution
                self.order_counts_dict[order] = self.order_counts_dict.get(order, 0) + 1

                self.data.append({
                    'text': text,
                    'box': normalized_box,
                    'page': page_num,
                    'id': item_id,
                    'label': label,
                    'parent_id': parent_id,
                    'order': order,
                    'file_idx': len(self.data)
                })
                self.order_counts += 1

        except Exception as e:
            print(f"Error processing {input_file}: {e}")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        encoding = self.tokenizer(
            item['text'],
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )

        return {
            'input_ids': encoding['input_ids'].squeeze(),
            'attention_mask': encoding['attention_mask'].squeeze(),
            'box': torch.tensor(item['box'], dtype=torch.float32),
            'page': torch.tensor(item['page'], dtype=torch.long),
            'label': item['label'],
            'id': item['id'],
            'parent_id': item['parent_id'],
            'order': torch.tensor(item['order'], dtype=torch.long),
            'file_idx': item['file_idx']
        }

def custom_collate_fn(batch):
    input_ids = torch.stack([item['input_ids'] for item in batch])
    attention_mask = torch.stack([item['attention_mask'] for item in batch])
    box = torch.stack([item['box'] for item in batch])
    page = torch.stack([item['page'] for item in batch])
    order = torch.stack([item['order'] for item in batch])
    labels = [item['label'] for item in batch]
    ids = [item['id'] for item in batch]
    file_idx = [item['file_idx'] for item in batch]
    parent_ids = [item['parent_id'] for item in batch]

    batch_size = len(batch)
    id_to_idx = {id_val: i for i, id_val in enumerate(ids)}
    linking_targets = torch.zeros(batch_size, dtype=torch.long)
    for i, parent_id in enumerate(parent_ids):
        if parent_id in id_to_idx:
            linking_targets[i] = id_to_idx[parent_id]
        else:
            linking_targets[i] = 0  # No parent (H1)

    return {
        'input_ids': input_ids,
        'attention_mask': attention_mask,
        'box': box,
        'page': page,
        'order': order,
        'label': labels,
        'id': ids,
        'file_idx': file_idx,
        'linking_targets': linking_targets
    }

class CompactDocumentModel(nn.Module):
    def __init__(self, num_labels, model_name='prajjwal1/bert-tiny'):
        super().__init__()
        self.text_encoder = AutoModel.from_pretrained(model_name)
        text_dim = self.text_encoder.config.hidden_size

        self.spatial_encoder = nn.Sequential(
            nn.Linear(5, 64),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(0.1)
        )

        combined_dim = text_dim + 128
        self.classifier = nn.Sequential(
            nn.Linear(combined_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, num_labels)
        )

        self.order_head = nn.Sequential(
            nn.Linear(combined_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 7)  # 7 classes for orders 0-6
        )

        self.feature_projector = nn.Linear(combined_dim, 256)

    def forward(self, input_ids, attention_mask, box, page):
        text_output = self.text_encoder(input_ids=input_ids, attention_mask=attention_mask)
        text_features = text_output.last_hidden_state[:, 0]

        spatial_input = torch.cat([box, page.unsqueeze(-1).float()], dim=-1)
        spatial_features = self.spatial_encoder(spatial_input)

        combined_features = torch.cat([text_features, spatial_features], dim=-1)
        label_logits = self.classifier(combined_features)
        order_pred = self.order_head(combined_features)
        linking_features = self.feature_projector(combined_features)

        return {
            'label_logits': label_logits,
            'order_pred': order_pred,
            'features': combined_features,
            'linking_features': linking_features
        }

class ImprovedLinkingPredictor(nn.Module):
    def __init__(self, feature_dim=256):
        super().__init__()
        self.attention = nn.MultiheadAttention(feature_dim, num_heads=8, batch_first=True)
        self.similarity_net = nn.Sequential(
            nn.Linear(feature_dim * 3 + 3, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.LayerNorm(256),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, features, boxes):
        batch_size, feature_dim = features.shape
        attended_features, _ = self.attention(
            features.unsqueeze(0), features.unsqueeze(0), features.unsqueeze(0)
        )
        attended_features = attended_features.squeeze(0)

        features_i = attended_features.unsqueeze(1).expand(-1, batch_size, -1)
        features_j = attended_features.unsqueeze(0).expand(batch_size, -1, -1)
        concat_features = torch.cat([features_i, features_j], dim=-1)
        product_features = features_i * features_j

        boxes_i = boxes.unsqueeze(1).expand(-1, batch_size, -1)
        boxes_j = boxes.unsqueeze(0).expand(batch_size, -1, -1)
        x_dist = (boxes_i[:, :, 0] - boxes_j[:, :, 0]).abs()
        y_dist = (boxes_i[:, :, 1] - boxes_j[:, :, 1]).abs()
        y_diff = boxes_i[:, :, 1] - boxes_j[:, :, 1]  # Vertical alignment
        spatial_dists = torch.stack([x_dist, y_dist, y_diff], dim=-1)

        pairs = torch.cat([concat_features, product_features, spatial_dists], dim=-1)
        linking_logits = self.similarity_net(pairs.reshape(-1, feature_dim * 3 + 3))
        linking_logits = linking_logits.reshape(batch_size, batch_size)

        mask = torch.eye(batch_size, device=linking_logits.device)
        linking_logits = linking_logits * (1 - mask) - 1e9 * mask  # Prevent self-linking
        return linking_logits

class DocumentTrainer:
    def __init__(self, model, linking_predictor, tokenizer, label_encoder, device):
        self.model = model
        self.linking_predictor = linking_predictor
        self.tokenizer = tokenizer
        self.label_encoder = label_encoder
        self.device = device
        self.model.to(device)
        self.linking_predictor.to(device)

    def train(self, train_loader, val_loader, num_epochs=20, save_path="./models"):
        os.makedirs(save_path, exist_ok=True)
        optimizer = torch.optim.AdamW([
            {'params': self.model.parameters(), 'lr': 5e-5},
            {'params': self.linking_predictor.parameters(), 'lr': 1e-5}
        ], weight_decay=0.01)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
        label_criterion = FocalLoss(alpha=0.75, gamma=2.0)
        order_criterion = nn.CrossEntropyLoss()  # Will compute weights dynamically
        linking_criterion = nn.CrossEntropyLoss()

        best_val_f1 = 0.0
        best_linking_threshold = 0.5
        patience = 30
        patience_counter = 0

        for epoch in range(num_epochs):
            print(f"\nEpoch {epoch+1}/{num_epochs}")
            self.model.train()
            self.linking_predictor.train()
            train_loss, train_label_acc, train_linking_acc = 0, 0, 0
            num_batches = 0

            # Compute dynamic order weights
            order_counts = train_loader.dataset.order_counts_dict
            total_orders = sum(order_counts.values())
            order_weights = torch.tensor([total_orders / (order_counts.get(i, 1) * 7) for i in range(7)], dtype=torch.float).to(self.device)
            order_criterion.weight = order_weights

            for batch in tqdm(train_loader, desc="Training"):
                optimizer.zero_grad()
                input_ids = batch['input_ids'].to(self.device)
                attention_mask = batch['attention_mask'].to(self.device)
                box = batch['box'].to(self.device)
                page = batch['page'].to(self.device)
                order = batch['order'].to(self.device)
                labels = torch.tensor(self.label_encoder.transform(batch['label']), dtype=torch.long).to(self.device)
                linking_targets = batch['linking_targets'].to(self.device)

                outputs = self.model(input_ids, attention_mask, box, page)
                label_loss = label_criterion(outputs['label_logits'], labels)
                order_loss = order_criterion(outputs['order_pred'], order.long())
                linking_logits = self.linking_predictor(outputs['linking_features'], box)
                linking_loss = linking_criterion(linking_logits, linking_targets)

                total_loss = label_loss + 0.5 * order_loss + 5.0 * linking_loss

                total_loss.backward()
                torch.nn.utils.clip_grad_norm_(list(self.model.parameters()) + list(self.linking_predictor.parameters()), 0.5)
                optimizer.step()

                train_loss += total_loss.item()
                pred_labels = torch.argmax(outputs['label_logits'], dim=1)
                train_label_acc += (pred_labels == labels).float().mean().item()
                linking_preds = torch.argmax(linking_logits, dim=1)
                train_linking_acc += (linking_preds == linking_targets).float().mean().item()
                num_batches += 1

            scheduler.step()
            val_loss, val_metrics = self.validate(val_loader, label_criterion, order_criterion, linking_criterion, best_linking_threshold)
            best_linking_threshold = self.optimize_threshold(val_loader)

            print(f"Train Loss: {train_loss/num_batches:.4f}, Train Acc: {train_label_acc/num_batches:.4f}, Train Linking Acc: {train_linking_acc/num_batches:.4f}")
            print(f"Val Loss: {val_loss:.4f}, Val Precision: {val_metrics['precision']:.4f}, Val Recall: {val_metrics['recall']:.4f}, Val F1: {val_metrics['f1']:.4f}, Val Linking Acc: {val_metrics['linking_acc']:.4f}, Val Acc: {val_metrics['accuracy']:.4f}, Linking Threshold: {best_linking_threshold:.4f}")

            if val_metrics['f1'] > best_val_f1:
                best_val_f1 = val_metrics['f1']
                self.save_model(save_path)
                print("Saved best model!")
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping at epoch {epoch+1}")
                    break

    def optimize_threshold(self, val_loader):
        self.model.eval()
        self.linking_predictor.eval()
        all_linking_probs, all_linking_targets = [], []
        thresholds = np.arange(0.3, 0.7, 0.05)
        best_acc, best_threshold = 0.0, 0.5

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch['input_ids'].to(self.device)
                attention_mask = batch['attention_mask'].to(self.device)
                box = batch['box'].to(self.device)
                page = batch['page'].to(self.device)
                linking_targets = batch['linking_targets'].to(self.device)
                outputs = self.model(input_ids, attention_mask, box, page)
                linking_logits = self.linking_predictor(outputs['linking_features'], box)
                linking_probs = torch.sigmoid(linking_logits)
                all_linking_probs.extend(linking_probs.cpu().numpy())
                all_linking_targets.extend(linking_targets.cpu().numpy())

        all_linking_probs = np.array(all_linking_probs)
        all_linking_targets = np.array(all_linking_targets)
        for thresh in thresholds:
            linking_preds = np.argmax(all_linking_probs, axis=1)
            linking_preds[all_linking_probs.max(axis=1) < thresh] = 0  # No parent if below threshold
            acc = sum(p == t for p, t in zip(linking_preds, all_linking_targets)) / len(all_linking_targets)
            if acc > best_acc:
                best_acc = acc
                best_threshold = thresh

        return best_threshold

    def validate(self, val_loader, label_criterion, order_criterion, linking_criterion, linking_threshold):
        self.model.eval()
        self.linking_predictor.eval()
        val_loss, all_preds, all_labels, all_linking_preds, all_linking_targets = 0, [], [], [], []
        num_batches = 0

        with torch.no_grad():
            for batch in tqdm(val_loader, desc="Validation"):
                input_ids = batch['input_ids'].to(self.device)
                attention_mask = batch['attention_mask'].to(self.device)
                box = batch['box'].to(self.device)
                page = batch['page'].to(self.device)
                order = batch['order'].to(self.device)
                labels = torch.tensor(self.label_encoder.transform(batch['label']), dtype=torch.long).to(self.device)
                linking_targets = batch['linking_targets'].to(self.device)

                outputs = self.model(input_ids, attention_mask, box, page)
                label_loss = label_criterion(outputs['label_logits'], labels)
                order_loss = order_criterion(outputs['order_pred'], order.long())
                linking_logits = self.linking_predictor(outputs['linking_features'], box)
                linking_loss = linking_criterion(linking_logits, linking_targets)

                total_loss = label_loss + 0.5 * order_loss + 5.0 * linking_loss
                val_loss += total_loss.item()
                pred_labels = torch.argmax(outputs['label_logits'], dim=-1)
                all_preds.extend(pred_labels.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
                linking_preds = torch.argmax(linking_logits, dim=1)
                all_linking_preds.extend(linking_preds.cpu().numpy())
                all_linking_targets.extend(linking_targets.cpu().numpy())
                num_batches += 1

        val_loss = val_loss / num_batches
        precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted', zero_division=0)
        linking_acc = sum(p == t for p, t in zip(all_linking_preds, all_linking_targets)) / len(all_linking_targets)
        accuracy = sum(p == l for p, l in zip(all_preds, all_labels)) / len(all_labels)

        return val_loss, {
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'linking_acc': linking_acc,
            'accuracy': accuracy
        }

    def save_model(self, save_path):
        torch.save(self.model.state_dict(), os.path.join(save_path, "document_model.pth"))
        torch.save(self.linking_predictor.state_dict(), os.path.join(save_path, "linking_predictor.pth"))
        with open(os.path.join(save_path, "label_encoder.pkl"), 'wb') as f:
            pickle.dump(self.label_encoder, f)

class FastInferenceModel:
    def __init__(self, model_path, linking_threshold=0.5):
        self.device = torch.device('cpu')
        self.linking_threshold = linking_threshold
        self.tokenizer = AutoTokenizer.from_pretrained('prajjwal1/bert-tiny')
        with open(os.path.join(model_path, "label_encoder.pkl"), 'rb') as f:
            self.label_encoder = pickle.load(f)

        self.model = CompactDocumentModel(num_labels=len(self.label_encoder.classes_))
        self.linking_predictor = ImprovedLinkingPredictor()
        self.model.load_state_dict(torch.load(os.path.join(model_path, "document_model.pth"), map_location='cpu'))
        self.linking_predictor.load_state_dict(torch.load(os.path.join(model_path, "linking_predictor.pth"), map_location='cpu'))
        self.model.eval()
        self.linking_predictor.eval()

    def predict(self, input_file):
        start_time = time.time()
        with open(input_file, 'r', encoding='utf-8') as f:
            data = json.load(f)

        items = data.get('contents', [])
        if not items:
            return []

        texts, boxes, pages, item_ids = [], [], [], []
        for item in items:
            text = item.get('text', '') or '[EMPTY]'
            texts.append(text)
            page_num = item.get('page', 1)
            page_info = data.get('pages', {}).get(f'page{page_num}', 
                                                 data.get('pages', {}).get(str(page_num), 
                                                 {'width': 1000, 'height': 1000}))
            box = item.get('box', [0, 0, 0, 0])
            normalized_box = [
                box[0] / page_info['width'],
                box[1] / page_info['height'],
                box[2] / page_info['width'],
                box[3] / page_info['height']
            ]
            boxes.append(normalized_box)
            pages.append(page_num)
            item_id = item.get('id', 0)
            if item_id == 0:
                continue
            item_ids.append(item_id)

        if not item_ids:
            return []

        encodings = self.tokenizer(texts, truncation=True, padding='max_length', max_length=64, return_tensors='pt')
        input_ids = encodings['input_ids'].to(self.device)
        attention_mask = encodings['attention_mask'].to(self.device)
        box_tensor = torch.tensor(boxes, dtype=torch.float32).to(self.device)
        page_tensor = torch.tensor(pages, dtype=torch.long).to(self.device)

        with torch.no_grad():
            outputs = self.model(input_ids, attention_mask, box_tensor, page_tensor)
            label_probs = torch.softmax(outputs['label_logits'], dim=-1)
            label_preds = torch.argmax(label_probs, dim=-1)
            order_preds = torch.argmax(outputs['order_pred'], dim=-1)
            linking_logits = self.linking_predictor(outputs['linking_features'], box_tensor)
            linking_probs = torch.sigmoid(linking_logits)

        try:
            with open(input_file.replace('input', 'output'), 'r', encoding='utf-8') as f:
                gt_data = json.load(f)
            gt_map = {item['id']: item for item in gt_data.get('contents', [])}
        except Exception as e:
            print(f"Error loading ground truth for {input_file}: {e}")
            gt_map = {}

        results = []
        for i in range(len(item_ids)):
            pred_label = self.label_encoder.inverse_transform([label_preds[i].item()])[0]
            if pred_label not in ['title', 'section-title']:
                continue
            max_prob, max_idx = torch.max(linking_probs[i], dim=0)
            parent_id = item_ids[max_idx] if max_prob.item() > self.linking_threshold and max_idx != i and item_ids[max_idx] != item_ids[i] else 0
            results.append({
                'id': item_ids[i],
                'label': pred_label,
                'parent_id': parent_id,
                'order': int(order_preds[i].item()),
                'confidence': label_probs[i, label_preds[i]].item(),
                'text': texts[i],
                'gt_text': gt_map.get(item_ids[i], {}).get('text', '')
            })

        inference_time = time.time() - start_time
        print(f"Inference completed in {inference_time:.2f} seconds")
        return results

class DocIENetPreprocessor:
    def __init__(self, dataset_path="../datasets/dochienet_dataset/dochienet_dataset/labels", input_dir="./input", output_dir="./output"):
        self.dataset_path = dataset_path
        self.input_dir = input_dir
        self.output_dir = output_dir
        os.makedirs(input_dir, exist_ok=True)
        os.makedirs(output_dir, exist_ok=True)

    def split_dataset(self):
        print("Processing DocIENet dataset...")
        if not os.path.exists(self.dataset_path):
            print(f"Dataset path {self.dataset_path} not found!")
            return [], []

        input_files, output_files, label_counts, order_counts = [], [], {}, {}
        print("Processing DocIENet dataset...")
        if not os.path.exists(self.dataset_path):
            print(f"Dataset path {self.dataset_path} not found!")
            return [], []

        input_files, output_files, label_counts, order_counts = [], [], {}, {}
        link_counts, discarded_links = 0, 0
        for filename in tqdm(os.listdir(self.dataset_path)):
            if filename.endswith('.json'):
                file_path = os.path.join(self.dataset_path, filename)
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        data = json.load(f)

                    # Validate IDs
                    valid_items = [item for item in data.get('contents', []) if item.get('label') in DocIENetDataset.VALID_LABELS]
                    valid_ids = {item['id'] for item in valid_items}
                    if not valid_ids:
                        continue

                    for item in data.get('contents', []):
                        if item.get('id', 0) == 0:
                            continue
                        label = item.get('label', 'other')
                        label_counts[label] = label_counts.get(label, 0) + 1
                        order = min(item.get('order', 0), 6)  # Cap at 6
                        order_counts[order] = order_counts.get(order, 0) + 1

                    input_data = {"pages": data.get("pages", {}), "contents": []}
                    output_data = {"contents": []}

                    for item in data.get('contents', []):
                        if item.get('id', 0) == 0:
                            continue
                        input_item = {
                            "box": item.get("box", [0, 0, 0, 0]),
                            "text": item.get("text", "") or "[EMPTY]",
                            "page": item.get("page", 1),
                            "id": item.get("id", 0)
                        }
                        input_data["contents"].append(input_item)

                    valid_items = sorted(valid_items, key=lambda x: x.get('order', 0))
                    order_map = {item['id']: idx for idx, item in enumerate(valid_items)}

                    for item in valid_items:
                        parent_id = 0
                        for link in item.get("linking", []):
                            if len(link) != 2:
                                continue
                            source_id, target_id = link
                            if source_id not in valid_ids or target_id not in valid_ids or source_id == 0 or target_id == 0:
                                discarded_links += 1
                                continue
                            if source_id == target_id:
                                print(f"Invalid self-link in {filename}: {link}")
                                discarded_links += 1
                                continue
                            parent_id = target_id
                            link_counts += 1
                            break

                        output_item = {
                            "id": item.get("id", 0),
                            "label": item.get("label", "other"),
                            "text": item.get("text", "") or "[EMPTY]",
                            "parent_id": parent_id,
                            "order": min(order_map.get(item.get("id", 0), 0), 6)
                        }
                        output_data["contents"].append(output_item)

                    if input_data["contents"] and output_data["contents"]:
                        input_file_path = os.path.join(self.input_dir, filename)
                        with open(input_file_path, 'w', encoding='utf-8') as f:
                            json.dump(input_data, f, indent=2, ensure_ascii=False)
                        input_files.append(input_file_path)
                        output_file_path = os.path.join(self.output_dir, filename)
                        with open(output_file_path, 'w', encoding='utf-8') as f:
                            json.dump(output_data, f, indent=2, ensure_ascii=False)
                        output_files.append(output_file_path)

                except Exception as e:
                    print(f"Error processing {filename}: {e}")
                    continue

        print(f"Processed {len(input_files)} files with valid labels")
        print(f"Input files saved to: {self.input_dir}")
        print(f"Output files saved to: {self.output_dir}")
        print(f"Label distribution: {label_counts}")
        print(f"Order distribution: {order_counts}")
        print(f"Total valid links: {link_counts}")
        print(f"Discarded links: {discarded_links}")
        return input_files, output_files

def main():
    print("=== Improved DocIENet Model Training (Titles & Section-Titles as Separate Labels) ===")
    preprocessor = DocIENetPreprocessor()
    input_files, output_files = preprocessor.split_dataset()

    if not input_files:
        print("No files with valid labels processed. Please check your dataset path.")
        return

    total_files = len(input_files)
    train_size = int(0.7 * total_files)
    val_size = int(0.1 * total_files)
    print(f"\nDataset split:")
    print(f"Total files: {total_files}")
    print(f"Train files: {train_size} (70%)")
    print(f"Validation files: {val_size} (10%)")
    print(f"Unused files: {total_files - train_size - val_size} (20%)")

    train_files = input_files[:train_size]
    train_output_files = output_files[:train_size]
    val_files = input_files[train_size:train_size + val_size]
    val_output_files = output_files[train_size:train_size + val_size]

    tokenizer = AutoTokenizer.from_pretrained('prajjwal1/bert-tiny')
    train_dataset = DocIENetDataset(train_files, train_output_files, tokenizer)
    val_dataset = DocIENetDataset(val_files, val_output_files, tokenizer, label_encoder=train_dataset.label_encoder)

    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, collate_fn=custom_collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, collate_fn=custom_collate_fn, drop_last=True)

    print(f"\nFinal dataset statistics:")
    print(f"Training samples: {len(train_dataset)}")
    print(f"Validation samples: {len(val_dataset)}")
    print(f"Number of labels: {len(train_dataset.label_encoder.classes_)}")
    print(f"Labels: {list(train_dataset.label_encoder.classes_)}")

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"\nUsing device: {device}")

    model = CompactDocumentModel(num_labels=len(train_dataset.label_encoder.classes_))
    linking_predictor = ImprovedLinkingPredictor()
    total_params = sum(p.numel() for p in model.parameters()) + sum(p.numel() for p in linking_predictor.parameters())
    print(f"Total model parameters: {total_params / 1e6:.1f}M")

    trainer = DocumentTrainer(model, linking_predictor, tokenizer, train_dataset.label_encoder, device)
    print("\nStarting training...")
    trainer.train(train_loader, val_loader, num_epochs=20)

    print("\nTraining completed!")
    print("\nTesting inference speed...")
    inference_model = FastInferenceModel("./models")

    if input_files:
        val = int(0.9 * len(input_files))
        test_file = input_files[val]
        print(f"Testing inference on {test_file}")
        results = inference_model.predict(test_file)
        with open(test_file.replace('input', 'output'), 'r', encoding='utf-8') as f:
            gt_data = json.load(f)
        gt_map = {item['id']: item for item in gt_data.get('contents', [])}

        print("\nComparison of predictions vs ground truth:")
        for pred in results:
            item_id = pred['id']
            gt = gt_map.get(item_id)
            if gt:
                print(f"ID: {item_id}")
                print(f"  Pred label: {pred['label']}, GT label: {gt['label']}")
                print(f"  Pred order: {pred['order']}, GT order: {gt['order']}")
                print(f"  Pred parent_id: {pred['parent_id']}")
                print(f"  GT parent_id: {gt['parent_id']}")
                print(f"  Text: {pred['text']}")
                print(f"  GT Text: {gt['text']}")
                print("---")
            else:
                print(f"ID {item_id} not found in ground truth.")

if __name__ == "__main__":
    main()
# Out:
# === Improved DocIENet Model Training (Titles & Section-Titles as Separate Labels) ===
# Processing DocIENet dataset...
# Processing DocIENet dataset...
#   2%|▏         | 26/1673 [00:00<00:06, 259.65it/s]
# Invalid self-link in 0e7omgnivu.json: [45, 45]
#  14%|█▎        | 227/1673 [00:00<00:03, 399.55it/s]
# Invalid self-link in 3a7h2bjvsd.json: [59, 59]
# Invalid self-link in 3r9kkzoe0w.json: [47, 47]
#  30%|██▉       | 498/1673 [00:01<00:02, 409.99it/s]
# Invalid self-link in 9k32ioql1u.json: [52, 52]
#  40%|███▉      | 663/1673 [00:01<00:02, 378.83it/s]
# Invalid self-link in dzn94rabzz.json: [117, 117]
#  47%|████▋     | 794/1673 [00:02<00:02, 399.56it/s]
# Invalid self-link in gmfpodbwtk.json: [8, 8]
# Invalid self-link in gzjxddaeib.json: [74, 74]
#  73%|███████▎  | 1217/1673 [00:03<00:01, 375.43it/s]
# Invalid self-link in px5oeccmer.json: [18, 18]
# Invalid self-link in qujwxfasz9.json: [54, 54]
#  80%|███████▉  | 1338/1673 [00:03<00:00, 384.57it/s]
# Invalid self-link in r64vvojkkg.json: [35, 35]
# Invalid self-link in sw0i4q5ky3.json: [134, 134]
#  82%|████████▏ | 1377/1673 [00:03<00:00, 315.17it/s]
# Invalid self-link in t5lcds2p8o.json: [57, 57]
#  87%|████████▋ | 1457/1673 [00:03<00:00, 349.79it/s]
# Invalid self-link in ud38bolmj8.json: [62, 62]
# 100%|██████████| 1673/1673 [00:04<00:00, 387.28it/s]
# Processed 1670 files with valid labels
# Input files saved to: ./input
# Output files saved to: ./output
# Label distribution: {'figure': 4776, 'text': 132155, 'toc-title': 264, 'table-of-content': 2019, 'section-title': 24301, 'footer': 7225, 'page-number': 10432, 'header': 9313, 'title': 2766, 'sub-title': 1433, 'table': 2586, 'figure-title': 1511, 'figure-caption': 1789, 'footnote': 3549, 'table-title': 968, 'table-caption': 1119, 'other': 872, 'endnote': 3573, 'equation': 722, 'sidebar': 410}
# Order distribution: {1: 1032, 2: 1670, 3: 1670, 4: 1670, 5: 1670, 6: 175822, 0: 28249}
# Total valid links: 23539
# Discarded links: 3528
#
# Dataset split:
# Total files: 1670
# Train files: 1169 (70%)
# Validation files: 167 (10%)
# Unused files: 334 (20%)
# Loading dataset: 1169it [00:34, 33.58it/s]
# Dataset loaded with 19255 samples
# Valid labels: ['section-title', 'title']
# Total valid links: 18457
# Total items with reassigned orders: 19255
# Order distribution in dataset: {0: 1169, 1: 1127, 2: 1095, 3: 1058, 4: 1013, 5: 963, 6: 12830}
# Loading dataset: 167it [00:04, 33.49it/s]
# Dataset loaded with 2638 samples
# Valid labels: ['section-title', 'title']
# Total valid links: 2490
# Total items with reassigned orders: 2638
# Order distribution in dataset: {0: 167, 1: 161, 2: 156, 3: 153, 4: 146, 5: 141, 6: 1714}
#
# Final dataset statistics:
# Training samples: 19255
# Validation samples: 2638
# Number of labels: 2
# Labels: ['section-title', 'title']
#
# Using device: cuda
# Total model parameters: 5.1M
#
# Starting training...
#
# Epoch 1/20
# Training: 100%|██████████| 2407/2407 [01:34<00:00, 25.47it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 59.60it/s]
# Train Loss: 584270580.5546, Train Acc: 0.9278, Train Linking Acc: 0.1251
# Val Loss: 509118542.9959, Val Precision: 0.9238, Val Recall: 0.9301, Val F1: 0.9247, Val Linking Acc: 0.1030, Val Acc: 0.9301, Linking Threshold: 0.3000
# Saved best model!
#
# Epoch 2/20
# Training: 100%|██████████| 2407/2407 [01:30<00:00, 26.65it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 60.73it/s]
# Train Loss: 581673987.4295, Train Acc: 0.9470, Train Linking Acc: 0.1243
# Val Loss: 509118542.9791, Val Precision: 0.9372, Val Recall: 0.9411, Val F1: 0.9355, Val Linking Acc: 0.1759, Val Acc: 0.9411, Linking Threshold: 0.3000
# Saved best model!
#
# Epoch 3/20
# Training: 100%|██████████| 2407/2407 [01:32<00:00, 26.00it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 55.96it/s]
# Train Loss: 585828536.8421, Train Acc: 0.9516, Train Linking Acc: 0.1231
# Val Loss: 509118492.3956, Val Precision: 0.9378, Val Recall: 0.9419, Val F1: 0.9373, Val Linking Acc: 0.2025, Val Acc: 0.9419, Linking Threshold: 0.3000
# Saved best model!
#
# Epoch 4/20
# Training: 100%|██████████| 2407/2407 [01:38<00:00, 24.48it/s]
# Validation: 100%|██████████| 329/329 [00:02<00:00, 144.68it/s]
# Train Loss: 586088161.2631, Train Acc: 0.9538, Train Linking Acc: 0.1268
# Val Loss: 509118490.8336, Val Precision: 0.9376, Val Recall: 0.9415, Val F1: 0.9383, Val Linking Acc: 0.2071, Val Acc: 0.9415, Linking Threshold: 0.3000
# Saved best model!
#
# Epoch 5/20
# Training: 100%|██████████| 2407/2407 [00:54<00:00, 44.24it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 60.49it/s]
# Train Loss: 580894951.2352, Train Acc: 0.9565, Train Linking Acc: 0.1273
# Val Loss: 509118490.8338, Val Precision: 0.9396, Val Recall: 0.9434, Val F1: 0.9399, Val Linking Acc: 0.1953, Val Acc: 0.9434, Linking Threshold: 0.3000
# Saved best model!
#
# Epoch 6/20
# Training: 100%|██████████| 2407/2407 [01:35<00:00, 25.10it/s]
# Validation: 100%|██████████| 329/329 [00:02<00:00, 153.31it/s]
# Train Loss: 582712566.9249, Train Acc: 0.9580, Train Linking Acc: 0.1257
# Val Loss: 509118490.8063, Val Precision: 0.9397, Val Recall: 0.9434, Val F1: 0.9402, Val Linking Acc: 0.2139, Val Acc: 0.9434, Linking Threshold: 0.3000
# Saved best model!
#
# Epoch 7/20
# Training: 100%|██████████| 2407/2407 [00:49<00:00, 48.92it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 60.98it/s]
# Train Loss: 583491546.4523, Train Acc: 0.9580, Train Linking Acc: 0.1232
# Val Loss: 509118490.8186, Val Precision: 0.9355, Val Recall: 0.9396, Val F1: 0.9364, Val Linking Acc: 0.2204, Val Acc: 0.9396, Linking Threshold: 0.3000
#
# Epoch 8/20
# Training: 100%|██████████| 2407/2407 [01:38<00:00, 24.49it/s]
# Validation: 100%|██████████| 329/329 [00:02<00:00, 161.30it/s]
# Train Loss: 581673932.1233, Train Acc: 0.9588, Train Linking Acc: 0.1258
# Val Loss: 509118490.7973, Val Precision: 0.9383, Val Recall: 0.9419, Val F1: 0.9392, Val Linking Acc: 0.2591, Val Acc: 0.9419, Linking Threshold: 0.3000
#
# Epoch 9/20
# Training: 100%|██████████| 2407/2407 [01:43<00:00, 23.16it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 60.84it/s]
# Train Loss: 586347804.0750, Train Acc: 0.9593, Train Linking Acc: 0.1278
# Val Loss: 509118438.6453, Val Precision: 0.9403, Val Recall: 0.9438, Val F1: 0.9388, Val Linking Acc: 0.2291, Val Acc: 0.9438, Linking Threshold: 0.3000
#
# Epoch 10/20
# Training: 100%|██████████| 2407/2407 [01:35<00:00, 25.13it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 62.85it/s]
# Train Loss: 588165409.4613, Train Acc: 0.9594, Train Linking Acc: 0.1266
# Val Loss: 509118386.5246, Val Precision: 0.9350, Val Recall: 0.9377, Val F1: 0.9360, Val Linking Acc: 0.2481, Val Acc: 0.9377, Linking Threshold: 0.3000
#
# Epoch 11/20
# Training: 100%|██████████| 2407/2407 [01:39<00:00, 24.20it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 63.13it/s]
# Train Loss: 586088147.2952, Train Acc: 0.9595, Train Linking Acc: 0.1275
# Val Loss: 509118386.6886, Val Precision: 0.9280, Val Recall: 0.9274, Val F1: 0.9277, Val Linking Acc: 0.2439, Val Acc: 0.9274, Linking Threshold: 0.3000
#
# Epoch 12/20
# Training: 100%|██████████| 2407/2407 [01:42<00:00, 23.54it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 62.65it/s]
# Train Loss: 585049506.0377, Train Acc: 0.9592, Train Linking Acc: 0.1247
# Val Loss: 509118386.4996, Val Precision: 0.9370, Val Recall: 0.9396, Val F1: 0.9380, Val Linking Acc: 0.2622, Val Acc: 0.9396, Linking Threshold: 0.3000
#
# Epoch 13/20
# Training: 100%|██████████| 2407/2407 [01:45<00:00, 22.80it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 64.08it/s]
# Train Loss: 586570372.0654, Train Acc: 0.9601, Train Linking Acc: 0.1241
# Val Loss: 509118386.6040, Val Precision: 0.9356, Val Recall: 0.9388, Val F1: 0.9367, Val Linking Acc: 0.2496, Val Acc: 0.9388, Linking Threshold: 0.3000
#
# Epoch 14/20
# Training: 100%|██████████| 2407/2407 [01:43<00:00, 23.35it/s]
# Validation: 100%|██████████| 329/329 [00:06<00:00, 54.26it/s]
# Train Loss: 579596666.0312, Train Acc: 0.9611, Train Linking Acc: 0.1250
# Val Loss: 509118334.5984, Val Precision: 0.9358, Val Recall: 0.9388, Val F1: 0.9369, Val Linking Acc: 0.2561, Val Acc: 0.9388, Linking Threshold: 0.3000
#
# Epoch 15/20
# Training: 100%|██████████| 2407/2407 [01:44<00:00, 23.12it/s]
# Validation: 100%|██████████| 329/329 [00:04<00:00, 66.04it/s]
# Train Loss: 585828476.9266, Train Acc: 0.9608, Train Linking Acc: 0.1242
# Val Loss: 509118334.5679, Val Precision: 0.9343, Val Recall: 0.9369, Val F1: 0.9353, Val Linking Acc: 0.2641, Val Acc: 0.9369, Linking Threshold: 0.3000
#
# Epoch 16/20
# Training: 100%|██████████| 2407/2407 [01:43<00:00, 23.33it/s]
# Validation: 100%|██████████| 329/329 [00:09<00:00, 35.14it/s]
# Train Loss: 581154611.7836, Train Acc: 0.9619, Train Linking Acc: 0.1254
# Val Loss: 509118334.3961, Val Precision: 0.9368, Val Recall: 0.9403, Val F1: 0.9378, Val Linking Acc: 0.2538, Val Acc: 0.9403, Linking Threshold: 0.3000
#
# Epoch 17/20
# Training: 100%|██████████| 2407/2407 [01:39<00:00, 24.11it/s]
# Validation: 100%|██████████| 329/329 [00:05<00:00, 64.24it/s]
# Train Loss: 581414273.8420, Train Acc: 0.9611, Train Linking Acc: 0.1289
# Val Loss: 509118334.5239, Val Precision: 0.9366, Val Recall: 0.9396, Val F1: 0.9377, Val Linking Acc: 0.2606, Val Acc: 0.9396, Linking Threshold: 0.3000
#
# Epoch 18/20
# Training: 100%|██████████| 2407/2407 [01:02<00:00, 38.30it/s]
# Validation: 100%|██████████| 329/329 [00:01<00:00, 198.35it/s]
# Train Loss: 582972229.9144, Train Acc: 0.9607, Train Linking Acc: 0.1218
# Val Loss: 509118334.4984, Val Precision: 0.9383, Val Recall: 0.9415, Val F1: 0.9393, Val Linking Acc: 0.2496, Val Acc: 0.9415, Linking Threshold: 0.3000
#
# Epoch 19/20
# Training: 100%|██████████| 2407/2407 [01:10<00:00, 34.28it/s]
# Validation: 100%|██████████| 329/329 [00:04<00:00, 66.39it/s]
# Train Loss: 584270526.9846, Train Acc: 0.9615, Train Linking Acc: 0.1276
# Val Loss: 509118334.5211, Val Precision: 0.9373, Val Recall: 0.9403, Val F1: 0.9384, Val Linking Acc: 0.2557, Val Acc: 0.9403, Linking Threshold: 0.3000
#
# Epoch 20/20
# Training: 100%|██████████| 2407/2407 [01:31<00:00, 26.26it/s]
# Validation: 100%|██████████| 329/329 [00:04<00:00, 76.81it/s]
# Train Loss: 586607458.8633, Train Acc: 0.9614, Train Linking Acc: 0.1277
# Val Loss: 509118334.5293, Val Precision: 0.9374, Val Recall: 0.9403, Val F1: 0.9385, Val Linking Acc: 0.2568, Val Acc: 0.9403, Linking Threshold: 0.3000
#
# Training completed!
#
# Testing inference speed...
# Testing inference on ./input\wl3rs78li0.json
# Inference completed in 0.16 seconds
#
# Comparison of predictions vs ground truth:
# ID: 1
#   Pred label: title, GT label: title
#   Pred order: 0, GT order: 0
#   Pred parent_id: 0
#   GT parent_id: 0
#   Text: 建设项目环境影响报告表
#   GT Text: 建设项目环境影响报告表
# ---
# ID 2 not found in ground truth.
# ID 3 not found in ground truth.
# ID 4 not found in ground truth.
# ID 5 not found in ground truth.
# ID 6 not found in ground truth.
# ID: 7
#   Pred label: section-title, GT label: section-title
#   Pred order: 3, GT order: 1
#   Pred parent_id: 0
#   GT parent_id: 7
#   Text: 1、建设项目基本情况
#   GT Text: 1、建设项目基本情况
# ---
# ID 8 not found in ground truth.
# ID: 9
#   Pred label: section-title, GT label: section-title
#   Pred order: 2, GT order: 2
#   Pred parent_id: 0
#   GT parent_id: 9
#   Text: [EMPTY]
#   GT Text: [EMPTY]
# ---
# ID 10 not found in ground truth.
# ID 11 not found in ground truth.
# ID 12 not found in ground truth.
# ID 13 not found in ground truth.
# ID 14 not found in ground truth.
# ID 15 not found in ground truth.
# ID 16 not found in ground truth.
# ID: 17
#   Pred label: section-title, GT label: section-title
#   Pred order: 2, GT order: 3
#   Pred parent_id: 0
#   GT parent_id: 17
#   Text: [EMPTY]
#   GT Text: [EMPTY]
# ---
# ID: 18
#   Pred label: section-title, GT label: section-title
#   Pred order: 2, GT order: 4
#   Pred parent_id: 0
#   GT parent_id: 18
#   Text: [EMPTY]
#   GT Text: [EMPTY]
# ---
# ID 19 not found in ground truth.
# ID 20 not found in ground truth.
# ID 21 not found in ground truth.
# ID 22 not found in ground truth.
# ID 23 not found in ground truth.
# ID 24 not found in ground truth.
# ID 25 not found in ground truth.
# ID 26 not found in ground truth.
# ID 27 not found in ground truth.
# ID: 28
#   Pred label: section-title, GT label: section-title
#   Pred order: 3, GT order: 5
#   Pred parent_id: 0
#   GT parent_id: 28
#   Text: [EMPTY]
#   GT Text: [EMPTY]
# ---
# ID 29 not found in ground truth.
# ID 30 not found in ground truth.
# ID 31 not found in ground truth.
# ID 32 not found in ground truth.
# ID 33 not found in ground truth.
# ID 34 not found in ground truth.
# ID 35 not found in ground truth.
# ID 36 not found in ground truth.
# ID 37 not found in ground truth.
# ID 38 not found in ground truth.
# ID 39 not found in ground truth.
# ID 40 not found in ground truth.
# ID 41 not found in ground truth.
# ID 42 not found in ground truth.
# ID 43 not found in ground truth.
# ID: 44
#   Pred label: section-title, GT label: section-title
#   Pred order: 6, GT order: 6
#   Pred parent_id: 0
#   GT parent_id: 44
#   Text: 1.2.3加油站等级
#   GT Text: 1.2.3加油站等级
# ---
# ID 45 not found in ground truth.
# ID 46 not found in ground truth.
# ID 47 not found in ground truth.
# ID 48 not found in ground truth.
# ID: 49
#   Pred label: section-title, GT label: section-title
#   Pred order: 6, GT order: 6
#   Pred parent_id: 0
#   GT parent_id: 49
#   Text: 1.2.4主要原辅材料
#   GT Text: 1.2.4主要原辅材料
# ---
# ID 50 not found in ground truth.
# ID 51 not found in ground truth.
# ID 52 not found in ground truth.
# ID 53 not found in ground truth.
# ID 54 not found in ground truth.
# ID 55 not found in ground truth.
# ID 56 not found in ground truth.
# ID 57 not found in ground truth.
# ID 58 not found in ground truth.

# %%
def extract_paragraphs_with_ocr(pdf_path):
    structured_blocks = []
    page_sizes = {}
    order = 0

    with pdfplumber.open(pdf_path) as pdf:
        for page_idx, page in enumerate(pdf.pages, 0):
            page_sizes[str(page_idx)] = {"width": page.width, "height": page.height}
            lines = list(page.extract_text_lines())
            if lines and any(line.get("text", "").strip() for line in lines) and len(lines) >= 5:
                for line in lines:
                    box = [line["x0"], line["top"], line["x1"], line["bottom"]]
                    if any(coord < 0 or coord > max(page.width, page.height) for coord in box):
                        continue
                    block = {
                        "box": box,
                        "text": line["text"] or "[EMPTY]",
                        "page": page_idx,
                        "id": order,
                        "order": order
                    }
                    structured_blocks.append(block)
                    order += 1
            else:
                try:
                    pil_img = page.to_image(resolution=300).original
                    ocr_text = pytesseract.image_to_string(pil_img, lang='eng')
                except Exception as e:
                    print(f"OCR failed for page {page_idx} in {pdf_path}: {e}")
                    ocr_text = "[EMPTY]"
                block = {
                    "box": [0, 0, page.width, page.height],
                    "text": ocr_text or "[EMPTY]",
                    "page": page_idx,
                    "id": order,
                    "order": order
                }
                structured_blocks.append(block)
                order += 1

    return {
        "pages": page_sizes,
        "contents": structured_blocks
    }

test_pdf_dir = './pdf_input'
test_output_dir = './json_input'
os.makedirs(test_output_dir, exist_ok=True)

for fname in os.listdir(test_pdf_dir):
    if fname.lower().endswith('.pdf'):
        in_pdf = os.path.join(test_pdf_dir, fname)
        out_json = os.path.join(test_output_dir, os.path.splitext(fname)[0] + ".json")
        doc = extract_paragraphs_with_ocr(in_pdf)
        with open(out_json, "w", encoding="utf-8") as f:
            json.dump(doc, f, indent=2, ensure_ascii=False)
        print(f"Processed: {fname} -> {out_json}")

def main():
    print("=== DocIENet Model Inference for PDF Input ===")
    input_dir = "./json_input"
    output_dir = "./pdf_output"
    os.makedirs(output_dir, exist_ok=True)
    input_files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if f.endswith('.json') and not f.endswith('_predictions.json')]

    if not input_files:
        print("No JSON files found in ./json_input. Please run preprocess_pdf.py.")
        return

    try:
        tokenizer = AutoTokenizer.from_pretrained('prajjwal1/bert-tiny')
    except Exception as e:
        print(f"Failed to load tokenizer from ./bert-tiny: {e}")
        return

    device = torch.device('cpu')
    print(f"\nUsing device: {device}")

    try:
        inference_model = FastInferenceModel("./models")
    except Exception as e:
        print(f"Failed to initialize FastInferenceModel: {e}")
        return

    for input_file in input_files:
        print(f"Testing inference on {input_file}")
        try:
            results = inference_model.predict(input_file)
            # Filter predictions with confidence > 0.8
            filtered_results = [pred for pred in results if pred['confidence'] > 0.7]
            output_file = os.path.join(output_dir, os.path.basename(input_file).replace('.json', '_predictions.json'))
            if filtered_results:
                with open(output_file, 'w', encoding='utf-8') as f:
                    json.dump(filtered_results, f, indent=2, ensure_ascii=False)
                print(f"Saved {len(filtered_results)} predictions to {output_file}")
            else:
                print(f"No predictions with confidence > 0.8 for {input_file}. Skipping output.")
            print("\nPredictions:")
            for pred in results:
                print(f"ID: {pred['id']}")
                print(f"  Pred label: {pred['label']}")
                print(f"  Pred order: {pred['order']}")
                print(f"  Pred parent_id: {pred['parent_id']}")
                print(f"  Text: {pred['text']}")
                print(f"  Confidence: {pred['confidence']:.4f}")
                print("---")
        except Exception as e:
            print(f"Error processing {input_file}: {e}")

if __name__ == "__main__":
    main()
# Out:
# Processed: DV_mini_project.pdf -> ./json_input\DV_mini_project.json
# Processed: file01.pdf -> ./json_input\file01.json
# Processed: file02.pdf -> ./json_input\file02.json
# Processed: file03.pdf -> ./json_input\file03.json
# Processed: file04.pdf -> ./json_input\file04.json
# Processed: file05.pdf -> ./json_input\file05.json
# Processed: Hackathon 2025 - Problem Statement Summary (1)b0ee386.pdf -> ./json_input\Hackathon 2025 - Problem Statement Summary (1)b0ee386.json
# === DocIENet Model Inference for PDF Input ===
#
# Using device: cpu
# Testing inference on ./json_input\DV_mini_project.json
# Error loading ground truth for ./json_input\DV_mini_project.json: [Errno 2] No such file or directory: './json_output\\DV_mini_project.json'
# Inference completed in 0.09 seconds
# Saved 45 predictions to ./pdf_output\DV_mini_project_predictions.json
#
# Predictions:
# ID: 1
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: DV Mini Project
#   Confidence: 0.5969
# ---
# ID: 2
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Group Members: Rohit Gupta- C132 -60004230115 , Soham Chandane - C151 -
#   Confidence: 0.8097
# ---
# ID: 3
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: 60004230205, Vedang Kakade - C176 - 60004230259
#   Confidence: 0.8720
# ---
# ID: 4
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: INDIA'S CROP DATA ANALYSIS
#   Confidence: 0.7319
# ---
# ID: 5
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Introduction
#   Confidence: 0.7398
# ---
# ID: 6
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: In response to the dynamic evolution anticipated within the agriculture sector, driven
#   Confidence: 0.8476
# ---
# ID: 7
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: by advancements in the Future Internet, a novel Business-to-Business collaboration
#   Confidence: 0.8242
# ---
# ID: 8
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: platform has been developed from the perspective of the agri-food industry. This
#   Confidence: 0.7935
# ---
# ID: 9
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: platform endeavors to streamline collaboration among diverse stakeholders across
#   Confidence: 0.8136
# ---
# ID: 10
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: associated business domains, fostering effectiveness and flexibility in their
#   Confidence: 0.5983
# ---
# ID: 11
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: interactions. Furthermore, this report stems from the culmination of efforts to
#   Confidence: 0.5062
# ---
# ID: 12
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: leverage extensive datasets on crop production in India spanning multiple years. The
#   Confidence: 0.7907
# ---
# ID: 13
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: primary objective is to harness this wealth of information to predict crop production
#   Confidence: 0.7755
# ---
# ID: 14
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: outcomes and unearth critical insights elucidating key indicators and metrics that
#   Confidence: 0.7617
# ---
# ID: 15
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: significantly influence agricultural productivity.
#   Confidence: 0.5077
# ---
# ID: 16
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Crop Diversity and Production Overview
#   Confidence: 0.5434
# ---
# ID: 17
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: ● Crop Diversity: A diverse range of 70 distinct types of crops is evident within the
#   Confidence: 0.7552
# ---
# ID: 18
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: dataset.
#   Confidence: 0.8396
# ---
# ID: 19
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: ● Total Production: Over the extensive timeframe from 1995 to 2015, cumulative
#   Confidence: 0.6270
# ---
# ID: 20
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: production figures amount to an impressive 141.18 billion units, underscoring the
#   Confidence: 0.5041
# ---
# ID: 21
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: magnitude of agricultural output.
#   Confidence: 0.5188
# ---
# ID: 22
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Total Area: This substantial production is spread across an expansive area
#   Confidence: 0.6491
# ---
# ID: 23
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: encompassing 2.95 billion units, indicative of the extensive cultivation practices in
#   Confidence: 0.6948
# ---
# ID: 24
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: place.
#   Confidence: 0.8571
# ---
# ID: 25
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: ● Average Seasonal Production: Furthermore, the data highlights an average
#   Confidence: 0.6958
# ---
# ID: 26
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: seasonal production of 427.53 thousand units of produce, illustrating the
#   Confidence: 0.5533
# ---
# ID: 27
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: consistent yield achieved over time.
#   Confidence: 0.8179
# ---
# ID: 28
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Key Performance Indicators (KPIs): These KPIs provide a comprehensive
#   Confidence: 0.8294
# ---
# ID: 29
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: overview of crop production dynamics, laying the foundation for further analysis
#   Confidence: 0.5913
# ---
# ID: 30
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: and strategic decision-making within the agricultural domain.
#   Confidence: 0.6978
# ---
# ID: 31
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: 15K
#
# Crops
#
# No. of Crops
#
# 1995
#
# 14bn
#
# 12bn
#
# F
# =|
#
# Total Production
#
# 4bn
#
# 2bn
#
# Qbn
#
# 71995
#
# 2000 2005
#
# 2000 2005 2010
#
# Years
# - .
# oO
# Po /
# m
# . Cc
# Oo
# oom
# | :
#
# 2010
#
# Crop Production
#
# @bn
#
# Years
#
# 2015
#
# | 0.0bn
#
# ho
# Se
# —
# Ln
#
#   Confidence: 0.5457
# ---
# ID: 32
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Production Trends
#   Confidence: 0.8175
# ---
# ID: 33
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: As depicted in the visual representation, the total production has exhibited an upward
#   Confidence: 0.7282
# ---
# ID: 34
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: trend over the specified period, reaching its peak in 2011. Subsequently, favorable
#   Confidence: 0.7001
# ---
# ID: 35
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: outcomes were observed in 2013. However, in 2015, production experienced a
#   Confidence: 0.8373
# ---
# ID: 36
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: significant decline, reaching an all-time low. Similar trends are observed in the
#   Confidence: 0.7550
# ---
# ID: 37
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: number of crops sown, with figures peaking between 2000 and 2005, reaching a high
#   Confidence: 0.7270
# ---
# ID: 38
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: of 16.67 thousand, before declining to a low of 0.56 thousand in 2015.
#   Confidence: 0.7860
# ---
# ID: 39
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Crop Categories
#   Confidence: 0.8372
# ---
# ID: 40
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: As depicted in the chart above, the top three grown categories are as follows: Cereals
#   Confidence: 0.7098
# ---
# ID: 41
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: with 2 million units, constituting 22.72% of the total; Pulses with 2 million units,
#   Confidence: 0.9136
# ---
# ID: 42
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: accounting for 20.89%; and Unknown with 1 million units, representing 14.96% of the
#   Confidence: 0.9019
# ---
# ID: 43
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: total. Conversely, Cash Crops and Others comprise less than 5% each, signifying their
#   Confidence: 0.9083
# ---
# ID: 44
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: comparatively lower contribution to the overall distribution.
#   Confidence: 0.8472
# ---
# ID: 45
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Crop Type Per Unit Area
#   Confidence: 0.8019
# ---
# ID: 46
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Crop type per unit area refers to the category of crop growing per unit of area. In this
#   Confidence: 0.6754
# ---
# ID: 47
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: context, cereals emerge as the predominant category, reaching a peak of 44
#   Confidence: 0.7372
# ---
# ID: 48
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: thousand units, while others lag significantly behind at only 308 units. The average
#   Confidence: 0.7775
# ---
# ID: 49
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: crop type per unit area is calculated at 16.42 thousand units.
#   Confidence: 0.7568
# ---
# ID: 50
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Data Origin
#   Confidence: 0.8745
# ---
# ID: 51
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: A map of India illustrating the Indian states from which this data originates.
#   Confidence: 0.5946
# ---
# ID: 52
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Insights
#   Confidence: 0.8570
# ---
# ID: 53
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: ● Seasonal Variations: Analysis reveals significant fluctuations in crop production
#   Confidence: 0.7595
# ---
# ID: 54
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: across different seasons, with peak production observed during the Kharif and
#   Confidence: 0.6648
# ---
# ID: 55
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Rabi seasons, indicating the influence of climatic factors on agricultural output.
#   Confidence: 0.7298
# ---
# ID: 56
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: ● Crop Diversity: The study highlights the rich diversity of crops cultivated across
#   Confidence: 0.6503
# ---
# ID: 57
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: various regions, with some districts exhibiting a wide range of crop varieties, while
#   Confidence: 0.8128
# ---
# ID: 58
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: others specialize in specific crops, underscoring the importance of regional
#   Confidence: 0.8659
# ---
# ID: 59
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: agricultural practices and preferences.
#   Confidence: 0.9059
# ---
# ID: 60
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: ● Yearly Production Trends: Examination of yearly production trends unveils
#   Confidence: 0.6922
# ---
# ID: 61
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: notable patterns and trends over time, with certain years witnessing substantial
#   Confidence: 0.7663
# ---
# ID: 62
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: increases or decreases in crop production, suggesting the impact of factors such
#   Confidence: 0.8664
# ---
# ID: 63
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: as weather conditions, technological advancements, and policy changes.
#   Confidence: 0.7730
# ---
# ID: 64
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: ● Predictive Modeling: Leveraging machine learning algorithms, predictive models
#   Confidence: 0.6482
# ---
# ID: 65
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: are developed to forecast crop production, providing valuable insights for
#   Confidence: 0.8110
# ---
# ID: 66
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: stakeholders to anticipate future agricultural trends, optimize resource allocation,
#   Confidence: 0.7642
# ---
# Testing inference on ./json_input\file01.json
# Error loading ground truth for ./json_input\file01.json: [Errno 2] No such file or directory: './json_output\\file01.json'
# Inference completed in 0.06 seconds
# Saved 22 predictions to ./pdf_output\file01_predictions.json
#
# Predictions:
# ID: 1
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Application form for grant of LTC advance
#   Confidence: 0.7982
# ---
# ID: 2
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: 1. Name of the Government Servant
#   Confidence: 0.7658
# ---
# ID: 3
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Designation
#   Confidence: 0.5078
# ---
# ID: 4
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: 2.
#   Confidence: 0.8537
# ---
# ID: 5
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Date of entering the Central Government
#   Confidence: 0.5701
# ---
# ID: 6
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 3.
#   Confidence: 0.8105
# ---
# ID: 7
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Service
#   Confidence: 0.5189
# ---
# ID: 8
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 4. PAY + SI + NPA
#   Confidence: 0.7205
# ---
# ID: 9
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Whether permanent or temporary
#   Confidence: 0.5769
# ---
# ID: 10
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 5.
#   Confidence: 0.7616
# ---
# ID: 11
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 6. Home Town as recorded in the Service Book
#   Confidence: 0.6245
# ---
# ID: 12
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Whether wife / husband is employed and if
#   Confidence: 0.5938
# ---
# ID: 13
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 7.
#   Confidence: 0.7984
# ---
# ID: 14
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: so whether entitled to LTC
#   Confidence: 0.5004
# ---
# ID: 15
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Whether the concession is to be availed for
#   Confidence: 0.6256
# ---
# ID: 16
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: visiting home town and if so block for which
#   Confidence: 0.6920
# ---
# ID: 17
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 8.
#   Confidence: 0.8351
# ---
# ID: 18
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: LTC is to be availed.
#   Confidence: 0.5724
# ---
# ID: 19
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: (a) If the concession is to visit anywhere in
#   Confidence: 0.6138
# ---
# ID: 20
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 9. India, the place to be visited.
#   Confidence: 0.8072
# ---
# ID: 21
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: (b) Block for which to be availed.
#   Confidence: 0.7475
# ---
# ID: 22
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Single rail fare/bus fare from the
#   Confidence: 0.5932
# ---
# ID: 23
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: headquarters to home town/place of visit by
#   Confidence: 0.6093
# ---
# ID: 24
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 10.
#   Confidence: 0.8144
# ---
# ID: 25
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: shortest route.
#   Confidence: 0.6436
# ---
# ID: 26
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Persons in respect of whom LTC is proposed to be availed.
#   Confidence: 0.5139
# ---
# ID: 27
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: S.No Name Age Relationship
#   Confidence: 0.5272
# ---
# ID: 28
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: 1.
#   Confidence: 0.9184
# ---
# ID: 29
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 2.
#   Confidence: 0.9246
# ---
# ID: 30
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 11. 3.
#   Confidence: 0.8702
# ---
# ID: 31
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 4.
#   Confidence: 0.8800
# ---
# ID: 32
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 5.
#   Confidence: 0.8712
# ---
# ID: 33
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 6.
#   Confidence: 0.8743
# ---
# ID: 34
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Amount of advance required. Rs.
#   Confidence: 0.7453
# ---
# ID: 35
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 12.
#   Confidence: 0.9072
# ---
# ID: 36
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: I declare that the particulars furnished above are true and correct to the best of my knowledge. I
#   Confidence: 0.6007
# ---
# ID: 37
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: undertake to produce the tickets for the outward journey within ten days of receipt of the advance.
#   Confidence: 0.5450
# ---
# ID: 38
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: In the event of cancellation of the journey or if I fail to produce the tickets within ten days of receipt of
#   Confidence: 0.7445
# ---
# ID: 39
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: advance, I undertake to refund the entire advance in one lump sum.
#   Confidence: 0.7957
# ---
# ID: 40
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Date
#   Confidence: 0.8500
# ---
# Testing inference on ./json_input\file02.json
# Error loading ground truth for ./json_input\file02.json: [Errno 2] No such file or directory: './json_output\\file02.json'
# Inference completed in 0.26 seconds
# Saved 202 predictions to ./pdf_output\file02_predictions.json
#
# Predictions:
# ID: 1
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Overview
#   Confidence: 0.5304
# ---
# ID: 2
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Foundation Level Extensions
#   Confidence: 0.7247
# ---
# ID: 3
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Version 1.0
#   Confidence: 0.8339
# ---
# ID: 4
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: International Software Testing Qualifications Board
#   Confidence: 0.7172
# ---
# ID: 5
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Copyright Notice
#   Confidence: 0.7005
# ---
# ID: 6
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: This document may be copied in its entirety, or extracts made, if the source is acknowledged.
#   Confidence: 0.5638
# ---
# ID: 7
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: International
#   Confidence: 0.5374
# ---
# ID: 8
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Overview
#   Confidence: 0.6783
# ---
# ID: 9
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Software Testing
#   Confidence: 0.7740
# ---
# ID: 10
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Foundation Level Extension – Agile Tester
#   Confidence: 0.7192
# ---
# ID: 11
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Qualifications Board
#   Confidence: 0.5776
# ---
# ID: 12
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Copyright © International Software Testing Qualifications Board (hereinafter called ISTQB®).
#   Confidence: 0.8086
# ---
# ID: 13
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Version 2014 Page 2 of 12 May 31, 2014
#   Confidence: 0.8676
# ---
# ID: 14
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: © International Software Testing Qualifications Board
#   Confidence: 0.7154
# ---
# ID: 15
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: International
#   Confidence: 0.7851
# ---
# ID: 16
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Overview
#   Confidence: 0.7833
# ---
# ID: 17
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Software Testing
#   Confidence: 0.5097
# ---
# ID: 18
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Foundation Level Extension – Agile Tester
#   Confidence: 0.5244
# ---
# ID: 19
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: Qualifications Board
#   Confidence: 0.8132
# ---
# ID: 20
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Revision History
#   Confidence: 0.8292
# ---
# ID: 21
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Version Date Remarks
#   Confidence: 0.7789
# ---
# ID: 22
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 0.1 18 JUNE 2013 Initial version
#   Confidence: 0.9418
# ---
# ID: 23
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 0.2 23 JULY 2013 WG reviewed and confirmed
#   Confidence: 0.9360
# ---
# ID: 24
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 0.3 6 NOV 2013 amended population and diagram
#   Confidence: 0.9088
# ---
# ID: 25
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 0.7 11 DEC 2013 Amended Business Outcomes and Chapters matching
#   Confidence: 0.9090
# ---
# ID: 26
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 0.8 20 DEC 2013 Working group updates on 0.7
#   Confidence: 0.9275
# ---
# ID: 27
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 1.0 31 MAY 2014 GA release for Agile Extension
#   Confidence: 0.9381
# ---
# ID: 28
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Version 2014 Page 3 of 12 May 31, 2014
#   Confidence: 0.8899
# ---
# ID: 29
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: © International Software Testing Qualifications Board
#   Confidence: 0.7337
# ---
# ID: 30
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: International
#   Confidence: 0.8555
# ---
# ID: 31
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Overview
#   Confidence: 0.7871
# ---
# ID: 32
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: Software Testing
#   Confidence: 0.6063
# ---
# ID: 33
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Foundation Level Extension – Agile Tester
#   Confidence: 0.5722
# ---
# ID: 34
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Qualifications Board
#   Confidence: 0.8770
# ---
# ID: 35
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Table of Contents
#   Confidence: 0.7909
# ---
# ID: 36
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Revision History .......................................................................................................................................... 3
#   Confidence: 0.8627
# ---
# ID: 37
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Table of Contents ........................................................................................................................................ 4
#   Confidence: 0.8533
# ---
# ID: 38
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: 1. Introduction to the Foundation Level Extensions ............................................................................ 6
#   Confidence: 0.8904
# ---
# ID: 39
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 2. Introduction to Foundation Level Agile Tester Extension ............................................................... 7
#   Confidence: 0.9308
# ---
# ID: 40
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 2.1 Intended Audience ..................................................................................................................... 7
#   Confidence: 0.9371
# ---
# ID: 41
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: 2.2 Career Paths for Testers ............................................................................................................ 7
#   Confidence: 0.9455
# ---
# ID: 42
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 2.3 Learning Objectives ................................................................................................................... 7
#   Confidence: 0.9469
# ---
# ID: 43
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 2.4 Entry Requirements ................................................................................................................... 8
#   Confidence: 0.9503
# ---
# ID: 44
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 2.5 Structure and Course Duration................................................................................................... 8
#   Confidence: 0.9467
# ---
# ID: 45
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 2.6 Keeping It Current...................................................................................................................... 9
#   Confidence: 0.9473
# ---
# ID: 46
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 3. Overview of the Foundation Level Extension – Agile Tester Syllabus......................................... 10
#   Confidence: 0.9402
# ---
# ID: 47
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 3.1 Business Outcomes ................................................................................................................. 10
#   Confidence: 0.9508
# ---
# ID: 48
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 3.2 Content.................................................................................................................................... 10
#   Confidence: 0.9517
# ---
# ID: 49
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: 4. References .......................................................................................................................................... 12
#   Confidence: 0.9356
# ---
# ID: 50
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 4.1 Trademarks ............................................................................................................................. 12
#   Confidence: 0.9475
# ---
# ID: 51
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 4.2 Documents and Web Sites....................................................................................................... 12
#   Confidence: 0.9471
# ---
# ID: 52
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: Version 2014 Page 4 of 12 May 31, 2014
#   Confidence: 0.8825
# ---
# ID: 53
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: © International Software Testing Qualifications Board
#   Confidence: 0.7393
# ---
# ID: 54
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: International
#   Confidence: 0.8686
# ---
# ID: 55
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Overview
#   Confidence: 0.7853
# ---
# ID: 56
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Software Testing
#   Confidence: 0.6336
# ---
# ID: 57
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: Foundation Level Extension – Agile Tester
#   Confidence: 0.5802
# ---
# ID: 58
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Qualifications Board
#   Confidence: 0.8886
# ---
# ID: 59
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: Acknowledgements
#   Confidence: 0.8212
# ---
# ID: 60
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: This document was produced by a team from the International Software Testing Qualifications Board
#   Confidence: 0.5233
# ---
# ID: 61
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: Foundation Level Working Group.
#   Confidence: 0.8466
# ---
# ID: 62
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: The Agile Extension team thanks the review team and the National Boards for their suggestions and input.
#   Confidence: 0.6616
# ---
# ID: 63
#   Pred label: title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: At the time the Foundation Level Agile Extension Syllabus was completed, the Agile Extension Working
#   Confidence: 0.5170
# ---
# ID: 64
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Group had the following membership: Rex Black (Chair), Bertrand Cornanguer (Vice Chair), Gerry
#   Confidence: 0.8305
# ---
# ID: 65
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Coleman (Learning Objectives Lead), Debra Friedenberg (Exam Lead), Alon Linetzki (Business Outcomes
#   Confidence: 0.8820
# ---
# ID: 66
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: and Marketing Lead), Tauhida Parveen (Editor), and Leo van der Aalst (Development Lead).
#   Confidence: 0.7799
# ---
# ID: 67
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Authors: Rex Black, Anders Claesson, Gerry Coleman, Bertrand Cornanguer, Istvan Forgacs, Alon
#   Confidence: 0.6779
# ---
# ID: 68
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Linetzki, Tilo Linz, Leo van der Aalst, Marie Walsh, and Stephan Weber.
#   Confidence: 0.7645
# ---
# ID: 69
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Internal Reviewers: Mette Bruhn-Pedersen, Christopher Clements, Alessandro Collino, Debra
#   Confidence: 0.7259
# ---
# ID: 70
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Friedenberg, Kari Kakkonen, Beata Karpinska, Sammy Kolluru, Jennifer Leger, Thomas Mueller, Tuula
#   Confidence: 0.7084
# ---
# ID: 71
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Pääkkönen, Meile Posthuma, Gabor Puhalla, Lloyd Roden, Marko Rytkönen, Monika Stoecklein-Olsen,
#   Confidence: 0.7211
# ---
# ID: 72
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Robert Treffny, Chris Van Bael, and Erik van Veenendaal.
#   Confidence: 0.7656
# ---
# ID: 73
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: The team thanks also the following persons, from the National Boards and the Agile expert community,
#   Confidence: 0.8080
# ---
# ID: 74
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: who participated in reviewing, commenting, and balloting of the Foundation Agile Extension Syllabus: Dani
#   Confidence: 0.7726
# ---
# ID: 75
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Almog, Richard Berns, Stephen Bird, Monika Bögge, Afeng Chai, Josephine Crawford, Tibor Csöndes,
#   Confidence: 0.8079
# ---
# ID: 76
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Huba Demeter, Arnaud Foucal, Cyril Fumery, Kobi Halperin, Inga Hansen, Hanne Hinz, Jidong Hu, Phill
#   Confidence: 0.6556
# ---
# ID: 77
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Isles, Shirley Itah, Martin Klonk, Kjell Lauren, Igal Levi, Rik Marselis, Johan Meivert, Armin Metzger, Peter
#   Confidence: 0.7681
# ---
# ID: 78
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Morgan, Ninna Morin, Ingvar Nordstrom, Chris O’Dea, Klaus Olsen, Ismo Paukamainen, Nathalie Phung,
#   Confidence: 0.7668
# ---
# ID: 79
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Helmut Pichler, Salvatore Reale, Stuart Reid, Hans Rombouts, Petri Säilynoja, Soile Sainio, Lars-Erik
#   Confidence: 0.7110
# ---
# ID: 80
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Sandberg, Dakar Shalom, Jian Shen, Marco Sogliani, Lucjan Stapp, Yaron Tsubery, Sabine Uhde,
#   Confidence: 0.7544
# ---
# ID: 81
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Stephanie Ulrich, Tommi Välimäki, Jurian Van de Laar, Marnix Van den Ent, António Vieira Melo, Wenye
#   Confidence: 0.8553
# ---
# ID: 82
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Xu, Ester Zabar, Wenqiang Zheng, Peter Zimmerer, Stevan Zivanovic, and Terry Zuo.
#   Confidence: 0.8634
# ---
# ID: 83
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: This document was formally approved for release by the General Assembly of the ISTQB® on May 31,
#   Confidence: 0.6452
# ---
# ID: 84
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 2014.
#   Confidence: 0.8877
# ---
# ID: 85
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Version 2014 Page 5 of 12 May 31, 2014
#   Confidence: 0.9027
# ---
# ID: 86
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: © International Software Testing Qualifications Board
#   Confidence: 0.7438
# ---
# ID: 87
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: International
#   Confidence: 0.8736
# ---
# ID: 88
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Overview
#   Confidence: 0.7829
# ---
# ID: 89
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Software Testing
#   Confidence: 0.6464
# ---
# ID: 90
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: Foundation Level Extension – Agile Tester
#   Confidence: 0.5854
# ---
# ID: 91
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Qualifications Board
#   Confidence: 0.8928
# ---
# ID: 92
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 1. Introduction to the Foundation Level Extensions
#   Confidence: 0.8987
# ---
# ID: 93
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: This overview document is intended for anyone with an interest in the ISTQB Foundation Level
#   Confidence: 0.5624
# ---
# ID: 94
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Extensions who wants a high-level introduction to the leading principles and an overview of the individual
#   Confidence: 0.8158
# ---
# ID: 95
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: extension syllabi.
#   Confidence: 0.8099
# ---
# ID: 96
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: From time to time, ISTQB will update this document to reflect any additional extensions that shall be
#   Confidence: 0.7824
# ---
# ID: 97
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: introduced for the Foundation Level, or to reflect major changes in existing ones. Publications of the
#   Confidence: 0.6570
# ---
# ID: 98
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: updated document will be available on the ISTQB website.
#   Confidence: 0.7712
# ---
# ID: 99
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: The ISTQB Foundation and Advanced Level syllabi have been defined and have been on the market for
#   Confidence: 0.7419
# ---
# ID: 100
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: some time. New topics emerge due to technology and methodology changes in the market which often
#   Confidence: 0.6694
# ---
# ID: 101
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: are brought into the ISTQB program as new Expert Level syllabi. However, not all topics are suited for the
#   Confidence: 0.7557
# ---
# ID: 102
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Expert Level. For this reason, the extension syllabi are established at the Foundation Level to expand the
#   Confidence: 0.6510
# ---
# ID: 103
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: ISTQB program to incorporate new or updated knowledge. New extensions shall be discussed and
#   Confidence: 0.7808
# ---
# ID: 104
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: introduced by the ISTQB periodically. Extensions may be established at the Advanced Level as well, but
#   Confidence: 0.8153
# ---
# ID: 105
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: that is beyond the scope of this document.
#   Confidence: 0.6506
# ---
# ID: 106
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: The following Foundation Level Extension syllabus has been released:
#   Confidence: 0.5988
# ---
# ID: 107
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text:  Agile Tester
#   Confidence: 0.7980
# ---
# ID: 108
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: In this document, each Foundation Level Extension syllabus is summarized and the associated Business
#   Confidence: 0.5671
# ---
# ID: 109
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Outcomes are stated. The Business Outcomes communicate what can be expected from a person who
#   Confidence: 0.8728
# ---
# ID: 110
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: achieves a Foundation Level Extension Certification in a particular subject area (e.g., Agile Tester), and
#   Confidence: 0.7532
# ---
# ID: 111
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: will outline the benefits for companies that are considering the development of specific testing skills at this
#   Confidence: 0.8506
# ---
# ID: 112
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: level.
#   Confidence: 0.9382
# ---
# ID: 113
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Version 2014 Page 6 of 12 May 31, 2014
#   Confidence: 0.9142
# ---
# ID: 114
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: © International Software Testing Qualifications Board
#   Confidence: 0.7445
# ---
# ID: 115
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: International
#   Confidence: 0.8762
# ---
# ID: 116
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Overview
#   Confidence: 0.7809
# ---
# ID: 117
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Software Testing
#   Confidence: 0.6547
# ---
# ID: 118
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Foundation Level Extension – Agile Tester
#   Confidence: 0.5907
# ---
# ID: 119
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Qualifications Board
#   Confidence: 0.8951
# ---
# ID: 120
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 2. Introduction to Foundation Level Agile Tester Extension
#   Confidence: 0.9247
# ---
# ID: 121
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: The certification for Foundation Level Extension – Agile Tester is designed for professionals who are
#   Confidence: 0.5603
# ---
# ID: 122
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: working within Agile environments. It is also for professionals who are planning to start implementing
#   Confidence: 0.7363
# ---
# ID: 123
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Agile methods in the near future, or are working within companies that plan to do so, The certification
#   Confidence: 0.7326
# ---
# ID: 124
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: provides an advantage for those who would like to know the required Agile activities, roles, methods, and
#   Confidence: 0.8450
# ---
# ID: 125
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: methodologies specific to their role.
#   Confidence: 0.9118
# ---
# ID: 126
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 2.1 Intended Audience
#   Confidence: 0.9429
# ---
# ID: 127
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: The Foundation Level Extension – Agile Tester qualification is aimed at four main groups of professionals:
#   Confidence: 0.6026
# ---
# ID: 128
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: 1. Professionals who have achieved in-depth testing experience in traditional methods and would
#   Confidence: 0.9299
# ---
# ID: 129
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: like to get an Agile Tester Certificate.
#   Confidence: 0.8054
# ---
# ID: 130
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 2. Junior professional testers who are just starting in the testing profession, have received the
#   Confidence: 0.9464
# ---
# ID: 131
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Foundation Level certificate, and would like to know more about the tester’s role in an Agile
#   Confidence: 0.7286
# ---
# ID: 132
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: environment.
#   Confidence: 0.8892
# ---
# ID: 133
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 3. Professionals who are relatively new to testing and are required to implement test approaches,
#   Confidence: 0.9436
# ---
# ID: 134
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: methods and techniques in their day to day job in Agile projects.
#   Confidence: 0.7795
# ---
# ID: 135
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 4. Professionals who are experienced in their role (including unit testing) and need more
#   Confidence: 0.9398
# ---
# ID: 136
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: understanding and knowledge about how to perform and manage testing on all levels in Agile
#   Confidence: 0.7232
# ---
# ID: 137
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: projects.
#   Confidence: 0.8613
# ---
# ID: 138
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: These professionals include people who are in roles such as testers, test analysts, test engineers, test
#   Confidence: 0.8696
# ---
# ID: 139
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: consultants, test managers, user acceptance testers, and software developers.
#   Confidence: 0.8465
# ---
# ID: 140
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: This Foundation Level Extension – Agile Tester certification may also be appropriate for anyone who
#   Confidence: 0.6440
# ---
# ID: 141
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: wants a deeper understanding of software testing in the Agile world, such as project managers, quality
#   Confidence: 0.6200
# ---
# ID: 142
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: managers, software development managers, business analysts, IT directors, and management
#   Confidence: 0.7763
# ---
# ID: 143
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: consultants.
#   Confidence: 0.8581
# ---
# ID: 144
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 2.2 Career Paths for Testers
#   Confidence: 0.9569
# ---
# ID: 145
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: Building on the Foundation Level, the Agile Tester Extension supports the definition of career paths for
#   Confidence: 0.5667
# ---
# ID: 146
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: professional testers. A person with the Agile Tester certificate has extended the broad understanding of
#   Confidence: 0.7386
# ---
# ID: 147
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: testing acquired at the Foundation Level to enable him or her to work effectively as a professional tester in
#   Confidence: 0.7541
# ---
# ID: 148
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: an Agile project.
#   Confidence: 0.7696
# ---
# ID: 149
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: People possessing an ISTQB Foundation Level Extension – Agile Tester certificate may use the Certified
#   Confidence: 0.7146
# ---
# ID: 150
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Tester Foundation Level acronym CTFL-AT.
#   Confidence: 0.6865
# ---
# ID: 151
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 2.3 Learning Objectives
#   Confidence: 0.9599
# ---
# ID: 152
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: In general, the Foundation Level syllabus is examinable at a K1 level, i.e., the candidate will recognize,
#   Confidence: 0.7807
# ---
# ID: 153
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: remember and recall terms and concepts stated in the Foundation Level syllabus.
#   Confidence: 0.6113
# ---
# ID: 154
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: In addition, all Foundation Level syllabus learning objectives are examinable at the same K- level in an
#   Confidence: 0.6861
# ---
# ID: 155
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: extension exam.
#   Confidence: 0.9161
# ---
# ID: 156
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Version 2014 Page 7 of 12 May 31, 2014
#   Confidence: 0.8617
# ---
# ID: 157
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: © International Software Testing Qualifications Board
#   Confidence: 0.7429
# ---
# ID: 158
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: International
#   Confidence: 0.8777
# ---
# ID: 159
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: Overview
#   Confidence: 0.7794
# ---
# ID: 160
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Software Testing
#   Confidence: 0.6592
# ---
# ID: 161
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Foundation Level Extension – Agile Tester
#   Confidence: 0.5941
# ---
# ID: 162
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Qualifications Board
#   Confidence: 0.8967
# ---
# ID: 163
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: That said, each extension level exam focuses on the learning objectives defined in that extension
#   Confidence: 0.8297
# ---
# ID: 164
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: syllabus. The relevant learning objectives at K1, K2, and K3 levels are provided at the beginning of each
#   Confidence: 0.7870
# ---
# ID: 165
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: chapter within each particular extension syllabus.
#   Confidence: 0.6678
# ---
# ID: 166
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 2.4 Entry Requirements
#   Confidence: 0.9475
# ---
# ID: 167
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: To be able to participate in a Foundation Level Extension – Agile Tester exam, candidates must have
#   Confidence: 0.7420
# ---
# ID: 168
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: obtained the ISTQB Foundation Level certificate.
#   Confidence: 0.8133
# ---
# ID: 169
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: 2.5 Structure and Course Duration
#   Confidence: 0.9395
# ---
# ID: 170
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: The Foundation Level Extension – Agile Tester syllabus has no shared or common elements with the
#   Confidence: 0.5158
# ---
# ID: 171
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Foundation Level syllabus.
#   Confidence: 0.7082
# ---
# ID: 172
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: The syllabi must be taught in the following minimum number of days:
#   Confidence: 0.7972
# ---
# ID: 173
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Syllabus Days
#   Confidence: 0.8092
# ---
# ID: 174
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Baseline: Foundation 3
#   Confidence: 0.8206
# ---
# ID: 175
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Extension: Agile Tester 2
#   Confidence: 0.7957
# ---
# ID: 176
#   Pred label: section-title
#   Pred order: 4
#   Pred parent_id: 0
#   Text: The following figure shows the structure of the Agile Tester Extension and its relationship to the
#   Confidence: 0.6859
# ---
# ID: 177
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Foundation Level.
#   Confidence: 0.8544
# ---
# ID: 178
#   Pred label: section-title
#   Pred order: 6
#   Pred parent_id: 0
#   Text: Version 2014 Page 8 of 12 May 31, 2014
# ...
#   Confidence: 0.7572
# ---
# ID: 23
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: PATHWAY OPTIONS
#   Confidence: 0.6488
# ---
# ID: 24
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: REGULAR PATHWAY DISTINCTION PATHWAY
#   Confidence: 0.6696
# ---
# ID: 25
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● 4 credits of Math - At least one math
#   Confidence: 0.7196
# ---
# ID: 26
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: course should be an AP Math class.
#   Confidence: 0.6181
# ---
# ID: 27
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: ● 4 credits of Math
#   Confidence: 0.8524
# ---
# ID: 28
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: ● 4 credits of Science- At least one
#   Confidence: 0.7344
# ---
# ID: 29
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: ● 4 credits of Science
#   Confidence: 0.8504
# ---
# ID: 30
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: science course should be an AP
#   Confidence: 0.5464
# ---
# ID: 31
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: ● 4 credits of STEM-designated electives
#   Confidence: 0.8315
# ---
# ID: 32
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Science class.
#   Confidence: 0.7595
# ---
# ID: 33
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Maintain an overall 2.85 GPA
#   Confidence: 0.8571
# ---
# ID: 34
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: ● 4 credits of STEM-designated electives
#   Confidence: 0.7569
# ---
# ID: 35
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Participate in a minimum of 3 STEM
#   Confidence: 0.8485
# ---
# ID: 36
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: - One must be a Computer
#   Confidence: 0.6470
# ---
# ID: 37
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: presentations/conferences each year
#   Confidence: 0.5315
# ---
# ID: 38
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Science/Technology Class
#   Confidence: 0.5474
# ---
# ID: 39
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: with a required minimum total of 12
#   Confidence: 0.8524
# ---
# ID: 40
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Maintain an overall 3.5 GPA
#   Confidence: 0.8014
# ---
# ID: 41
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: presentations/conferences throughout
#   Confidence: 0.5589
# ---
# ID: 42
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Participate in a minimum of 3 STEM
#   Confidence: 0.7921
# ---
# ID: 43
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: the 4 years. *
#   Confidence: 0.9011
# ---
# ID: 44
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: presentations/conferences a year with a
#   Confidence: 0.5754
# ---
# ID: 45
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Join and actively participate in a
#   Confidence: 0.8434
# ---
# ID: 46
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: required minimum total of 12
#   Confidence: 0.7992
# ---
# ID: 47
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: STEM-related extracurricular activity or
#   Confidence: 0.6133
# ---
# ID: 48
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: presentations/conferences throughout
#   Confidence: 0.5187
# ---
# ID: 49
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: club every year of attendance. -
#   Confidence: 0.6510
# ---
# ID: 50
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: the 4 years.
#   Confidence: 0.8619
# ---
# ID: 51
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Join and actively participate in a
#   Confidence: 0.7939
# ---
# ID: 52
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: STEM-related extracurricular activity or
#   Confidence: 0.5344
# ---
# ID: 53
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: club every year of attendance.
#   Confidence: 0.5734
# ---
# ID: 54
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: ● Either participate in an internship or
#   Confidence: 0.7589
# ---
# ID: 55
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: design and implement a community
#   Confidence: 0.5404
# ---
# Testing inference on ./json_input\file05.json
# Error loading ground truth for ./json_input\file05.json: [Errno 2] No such file or directory: './json_output\\file05.json'
# Inference completed in 0.03 seconds
# Saved 4 predictions to ./pdf_output\file05_predictions.json
#
# Predictions:
# ID: 1
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: ADDRESS:
#   Confidence: 0.7561
# ---
# ID: 2
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: TOPJUMP
#   Confidence: 0.5550
# ---
# ID: 3
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: 3735 PARKWAY
#   Confidence: 0.7173
# ---
# ID: 4
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: PIGEON FORGE, TN 37863
#   Confidence: 0.6341
# ---
# ID: 5
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: (NEAR DIXIE STAMPEDE ON THE PARKWAY)
#   Confidence: 0.6196
# ---
# ID: 6
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: RSVP: ----------------
#   Confidence: 0.6042
# ---
# ID: 7
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: CLOSED TOED SHOES ARE REQUIRED FOR CLIMBING
#   Confidence: 0.5389
# ---
# ID: 8
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: PARENTS OR GUARDIANS NOT ATTENDING THE PARTY,
#   Confidence: 0.7277
# ---
# ID: 9
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: PLEASE VISIT TOPJUMP.COM TO FILL OUT WAIVER
#   Confidence: 0.6137
# ---
# ID: 10
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: SO YOUR CHILD CAN ATTEND.
#   Confidence: 0.7895
# ---
# ID: 11
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: HOPE To SEE You THERE!
#   Confidence: 0.5723
# ---
# Testing inference on ./json_input\Hackathon 2025 - Problem Statement Summary (1)b0ee386.json
# Error loading ground truth for ./json_input\Hackathon 2025 - Problem Statement Summary (1)b0ee386.json: [Errno 2] No such file or directory: './json_output\\Hackathon 2025 - Problem Statement Summary (1)b0ee386.json'
# Inference completed in 0.07 seconds
# Saved 24 predictions to ./pdf_output\Hackathon 2025 - Problem Statement Summary (1)b0ee386_predictions.json
#
# Predictions:
# ID: 1
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Shell.ai Hackathon 2025
#   Confidence: 0.5277
# ---
# ID: 2
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Problem statement summary
#   Confidence: 0.5225
# ---
# ID: 3
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Fuel Blend Properties Prediction Challenge
#   Confidence: 0.7294
# ---
# ID: 4
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Introduction
#   Confidence: 0.8082
# ---
# ID: 5
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Welcome to the sixth edition of the Shell.ai Hackathon for Sustainable and Affordable
#   Confidence: 0.7885
# ---
# ID: 6
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: Energy. Shell.ai Hackathon brings together brilliant minds passionate about digital solutions
#   Confidence: 0.7536
# ---
# ID: 7
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: and AI, to tackle real energy challenges and help build a lower-carbon world where
#   Confidence: 0.6728
# ---
# ID: 8
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: everyone can access and afford energy. In the previous five editions, we addressed some of
#   Confidence: 0.5220
# ---
# ID: 9
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: the digital challenges around the energy transition: windfarm layout optimisation (2020),
#   Confidence: 0.8013
# ---
# ID: 10
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: irradiance forecasting for solar power generation (2021), optimal placement of electric
#   Confidence: 0.8081
# ---
# ID: 11
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: vehicle (EV) charging stations (2022), supply chain optimisation for biorefineries (2023),
#   Confidence: 0.7277
# ---
# ID: 12
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: and fleet decarbonisation (2024). This year, we focus on blend properties estimation for
#   Confidence: 0.6250
# ---
# ID: 13
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: sustainable fuel.
#   Confidence: 0.6258
# ---
# ID: 14
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: Challenge
#   Confidence: 0.8677
# ---
# ID: 15
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: The global call for sustainability is reshaping every industry, including mobility, shipping and
#   Confidence: 0.6125
# ---
# ID: 16
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: aviation. For example, use of fuels like Sustainable Aviation Fuels (SAFs), renewable diesel,
#   Confidence: 0.7492
# ---
# ID: 17
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: and advanced bioethanol, among others has the potential to reduce the sector's
#   Confidence: 0.6718
# ---
# ID: 18
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: environmental footprint. However, integrating these innovative fuels into the existing
#   Confidence: 0.6274
# ---
# ID: 19
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: ecosystem presents a challenge. Crafting the optimal fuel blend – mixing various sustainable
#   Confidence: 0.8456
# ---
# ID: 20
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: fuel types sourced from diverse pathways with each other or with conventional fuels – is an
#   Confidence: 0.6906
# ---
# ID: 21
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: intricate science. It demands a delicate balancing act: ensuring adherence to rigorous safety
#   Confidence: 0.7986
# ---
# ID: 22
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: and performance specifications while maximizing environmental benefits and maintaining
#   Confidence: 0.5886
# ---
# ID: 23
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: economic viability.
#   Confidence: 0.5800
# ---
# ID: 24
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: In this hackathon, you will immerse yourselves in the critical field of fuel blending. Your
#   Confidence: 0.6106
# ---
# ID: 25
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: challenge is to develop models capable of predicting the final properties of complex fuel
#   Confidence: 0.7973
# ---
# ID: 26
#   Pred label: title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: blends based on their constituent components and proportions. By exploring datasets rich
#   Confidence: 0.5694
# ---
# ID: 27
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: with complex interactions, you will decipher the hidden relationships that dictate fuel
#   Confidence: 0.7987
# ---
# ID: 28
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: performance, safety, regulatory and environmental characteristics. The endgame is to
#   Confidence: 0.5470
# ---
# ID: 29
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: engineer powerful predictive tools that can guide the industry in formulating the next
#   Confidence: 0.7810
# ---
# ID: 30
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: generation of sustainable fuels, potentially accelerating the transition to a net-zero future,
#   Confidence: 0.7549
# ---
# ID: 31
#   Pred label: section-title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: without compromising on model excellence.
#   Confidence: 0.5479
# ---
# ID: 32
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: Data
#   Confidence: 0.8904
# ---
# ID: 33
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: To tackle this challenge, you will be equipped with a dataset reflecting the complexities of
#   Confidence: 0.6483
# ---
# ID: 34
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: fuel blending. At a high level, this dataset will feature:
#   Confidence: 0.7838
# ---
# ID: 35
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: 1. Fuel Component Library: An overview of the potential base components, including
#   Confidence: 0.6126
# ---
# ID: 36
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: various sustainable and conventional fuel types.
#   Confidence: 0.5612
# ---
# ID: 37
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: 2. Blend Composition Data: A significant number of diverse fuel blend examples,
#   Confidence: 0.8501
# ---
# ID: 38
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: detailing the precise fractional makeup of each blend.
#   Confidence: 0.6330
# ---
# ID: 39
#   Pred label: section-title
#   Pred order: 5
#   Pred parent_id: 0
#   Text: 3. Resultant Blend Properties: The corresponding key characteristics/properties
#   Confidence: 0.8514
# ---
# ID: 40
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: measured or calculated for each of these blends.
#   Confidence: 0.7675
# ---
# ID: 41
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: We will challenge you to develop models that can accurately predict these resultant
#   Confidence: 0.6528
# ---
# ID: 42
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: properties when given new, unseen blend compositions.
#   Confidence: 0.6005
# ---
# ID: 43
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Further, more granular details regarding the specific components, the full list of properties,
#   Confidence: 0.7378
# ---
# ID: 44
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: the size of the dataset, and the exact format required for your submissions will be shared in
#   Confidence: 0.6551
# ---
# ID: 45
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: the detailed problem statement, to be released closer to the hackathon date.
#   Confidence: 0.6739
# ---
# ID: 46
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: This is a challenge that will call for your expertise in mathematical modelling and machine
#   Confidence: 0.6223
# ---
# ID: 47
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: learning. We do not expect you to have any prior knowledge in fuel blending. To create a
#   Confidence: 0.8351
# ---
# ID: 48
#   Pred label: section-title
#   Pred order: 3
#   Pred parent_id: 0
#   Text: level playing field, we will not provide the exact property names and scale the values to
#   Confidence: 0.8586
# ---
# ID: 49
#   Pred label: section-title
#   Pred order: 2
#   Pred parent_id: 0
#   Text: make it impossible to guess.
#   Confidence: 0.7905
# ---
# ID: 50
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: Please note that for the purposes of this challenge, the term “sustainable fuels”
#   Confidence: 0.6801
# ---
# ID: 51
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: encompasses fuels derived from renewable or low-carbon sources; such as bio-based
#   Confidence: 0.6201
# ---
# ID: 52
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: feedstocks, synthetic fuels generated using renewable electricity (e-fuels), and fuels
#   Confidence: 0.6566
# ---
# ID: 53
#   Pred label: section-title
#   Pred order: 1
#   Pred parent_id: 0
#   Text: produced from waste materials. These alternatives are intended to significantly reduce
#   Confidence: 0.6344
# ---
# ID: 54
#   Pred label: title
#   Pred order: 0
#   Pred parent_id: 0
#   Text: lifecycle greenhouse gas emissions when compared to conventional fossil fuels.
#   Confidence: 0.5127
# ---
